# %% [markdown]
# <a href="https://colab.research.google.com/github/Imsurajr/OpenCV/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2
image = cv2.imread("/content/download (1).jpeg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.title("Original")
plt.imshow(image_rgb)

# %%
gray_image = cv2.imread("/content/download (1).jpeg" , cv2.COLOR_BGR2GRAY)

cv2.imwrite("/content/download (1).jpeg",gray_image)

plt.title("Gray-Scale")
plt.imshow(gray_image)

# %%
img = cv2.imread("/content/download (1).jpeg")

plt.title("Saved Image")
plt.imshow(img)
